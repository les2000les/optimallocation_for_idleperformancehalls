# %%
from datetime import timedelta

# %%
from datetime import datetime
import pandas as pd
import numpy as np

# %%
dates = [datetime(2023,2,11), datetime(2023,2,12), datetime(2023,2,13), datetime(2023,2,14), datetime(2023,2,15)]
dates
# Out:
# [datetime.datetime(2023, 2, 11, 0, 0),
#  datetime.datetime(2023, 2, 12, 0, 0),
#  datetime.datetime(2023, 2, 13, 0, 0),
#  datetime.datetime(2023, 2, 14, 0, 0),
#  datetime.datetime(2023, 2, 15, 0, 0)]

# %%
ts1 = pd.Series(np.arange(5), index = dates)
ts1
# Out:
# 2023-02-11    0
# 2023-02-12    1
# 2023-02-13    2
# 2023-02-14    3
# 2023-02-15    4
# dtype: int32

# %%
df = pd.DataFrame({'Naver': [100, 101, 103, 105],
'Kakao': [90, 100, 110, 90]},
index = pd.date_range('2019-08-01', periods = 4, freq = 'B'))
df
# Out:
#             Naver  Kakao
# 2019-08-01    100     90
# 2019-08-02    101    100
# 2019-08-05    103    110
# 2019-08-06    105     90

# %%
df.resample('D').ffill()
# Out:
#             Naver  Kakao
# 2019-08-01    100     90
# 2019-08-02    101    100
# 2019-08-03    101    100
# 2019-08-04    101    100
# 2019-08-05    103    110
# 2019-08-06    105     90

# %%
df.resample('D').ffill(limit=1)

# %%
pip install pandas_datareader
# Out:
# ...
#                                               0.0/109.5 kB ? eta -:--:--
#      -------------------------------------- 109.5/109.5 kB 6.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#      --                                       0.4/7.6 MB 8.5 MB/s eta 0:00:01
#      -----                                    1.1/7.6 MB 11.7 MB/s eta 0:00:01
#      ----------                               2.0/7.6 MB 14.0 MB/s eta 0:00:01
#      ----------------                         3.1/7.6 MB 16.3 MB/s eta 0:00:01
#      ----------------------                   4.3/7.6 MB 18.5 MB/s eta 0:00:01
#      -----------------------------            5.6/7.6 MB 21.2 MB/s eta 0:00:01
#      -------------------------------------    7.1/7.6 MB 21.8 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 21.2 MB/s eta 0:00:00
# ...
#                                               0.0/470.4 kB ? eta -:--:--
#      ------------------------------------- 470.4/470.4 kB 30.7 MB/s eta 0:00:00
# ...
#                                               0.0/1.9 MB ? eta -:--:--
# ...

# %%
import pandas_datareader.data as web
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start = datetime(2023,1,1)
end = datetime.now()

# %%
import yfinance as yf

apple = yf.download("AAPL", start=start, end=end)
ms = yf.download("MSFT", start=start, end=end)
coupang =  yf.download("CPNG", start=start, end=end)


coupang
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2023-01-03  15.030000  15.370000  14.710000  14.920000  14.920000   7391500
# 2023-01-04  15.270000  15.725000  15.020000  15.630000  15.630000   8263200
# 2023-01-05  15.400000  16.000000  15.400000  15.810000  15.810000   7161600
# 2023-01-06  15.960000  16.950001  15.840000  16.709999  16.709999   8118800
# 2023-01-09  17.000000  17.950001  16.840000  17.870001  17.870001  11765000
# ...               ...        ...        ...        ...        ...       ...
# 2023-06-26  16.510000  16.900000  16.059999  16.070000  16.070000  10075800
# 2023-06-27  16.260000  17.440001  16.160000  17.320000  17.320000  15507800
# 2023-06-28  17.090000  17.760000  17.059999  17.200001  17.200001   8858000
# ...

# %%
samsung = yf.download("005930.KS", start=start, end=end)
samsung
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2023-01-02  55500.0  56100.0  55200.0  55500.0  55180.453125  10031448
# 2023-01-03  55400.0  56000.0  54500.0  55400.0  55081.031250  13547030
# 2023-01-04  55700.0  58000.0  55600.0  57800.0  57467.210938  20188071
# 2023-01-05  58200.0  58800.0  57600.0  58200.0  57864.910156  15682826
# 2023-01-06  58300.0  59400.0  57900.0  59000.0  58660.304688  17334989
# ...             ...      ...      ...      ...           ...       ...
# 2023-06-26  71700.0  72500.0  71500.0  72400.0  72400.000000  10541901
# 2023-06-27  72500.0  72600.0  72000.0  72600.0  72600.000000   9442997
# 2023-06-28  72600.0  72700.0  72000.0  72700.0  72700.000000   8783093
# 2023-06-29  73100.0  73400.0  72400.0  72400.0  72400.000000  12229967
# 2023-06-30  72500.0  72700.0  71700.0  72200.0  72200.000000  11694765
#
# [123 rows x 6 columns]
